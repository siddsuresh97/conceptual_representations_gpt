# %%
#  Ganked from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
# Assumes you have run `pip install numpy pandas matplotlib scikit-learn seaborn`

# Standard imports
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# For this example we'll use Seaborn, which has some nice built in plots
import seaborn as sns

corr = pd.read_csv('../results/correlation_table.csv', index_col=1, header=0)
corr = corr.iloc[:, 1:]
# replace all the float values with the square of the float values
corr = corr.applymap(lambda x: x**2)
corr

#rename rows and columns using the follwing list
names = ['Human norms', 'Word2Vec', 'CLIP', 'GPT(unver)', 'GPT(ver)', 'Human triplet', 'GPT triplet', 'GPT embedding', 'Flan xl (ver)',  'Flan xxl (ver)', 'Human Pairwise', 'GPT Pairwise']
corr.index = names
corr.columns = names

#rearange the rows and columns to match the following order
names = ['Human norms', 'Human triplet', 'Human Pairwise', 'GPT(ver)', 'GPT triplet', 'GPT Pairwise','GPT(unver)', 'GPT embedding', 'Flan xl (ver)',  'Flan xxl (ver)', 'Word2Vec', 'CLIP']
corr = corr.reindex(names)
corr = corr.reindex(names, axis=1)



# # Generate a mask for the upper triangle; True = do NOT show
# mask = np.zeros_like(corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmap = plt.cm.YlOrRd

# Draw the heatmap with the mask and correct aspect ratio
# More details at https://seaborn.pydata.org/generated/seaborn.heatmap.html
sns.heatmap(
    corr,          # The data to plot
    # mask=mask,     # Mask some cells
    cmap=cmap,     # What colors to plot the heatmap as
    annot=True,    # Should the values be plotted in the cells?
    vmax=1,       # The maximum value of the legend. All higher vals will be same color
    vmin=0,      # The minimum value of the legend. All lower vals will be same color
    center=0.5,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .5}  # Extra kwargs for the legend; in this case, shrink by 50%
)
#remove the y-axis label
ax.set_ylabel('')

# Increase the size of the labels of make the resolution better
ax.tick_params(axis='both', which='major', labelsize=14)

#make the font such that it can be edited in illustrator
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#save the figure as a pdf
plt.savefig('../graphs/heatmap.pdf', bbox_inches='tight')
# Out:
# Failed to start the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
!#  Ganked from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
# Assumes you have run `pip install numpy pandas matplotlib scikit-learn seaborn`

# Standard imports
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# For this example we'll use Seaborn, which has some nice built in plots
import seaborn as sns

corr = pd.read_csv('../results/the_whole_correlation_table.csv', index_col=1, header=0)
corr = corr.iloc[:, 1:]
# replace all the float values with the square of the float values
corr = corr.applymap(lambda x: x**2)
corr

#rename rows and columns using the follwing list
names = ['Human norms', 'Word2Vec', 'CLIP', 'GPT3(002)(unver)', 'GPT3(002)(ver)', 'Human triplet', 'GPT3(002) triplet', 'GPT embedding', 'FLAN xl (ver)',  'FLAN xxl (ver)', 'Human Pairwise', 'GPT3(003) Pairwise', 
         'FLAN-XXL Triplet',  'FLAN-XXL COT Triplet', 'FLAN-UL2 Triplet',  'FLAN-UL2 COT Triplet', 'GPT3(003) COT Triplet', 'GPT3(002) COT Triplet', 'FLAN-UL2 Pairwise',  'FLAN-UL2 COT Pairwise', 'GPT3(003) COT Pairwise', 'GPT3(002) COT Pairwise']


corr.index = names
corr.columns = names

#rearange the rows and columns to match the following order
names = ['Human norms', 'Human triplet', 'Human Pairwise', 'GPT3(002)(ver)', 'GPT3(002) triplet',  'GPT3(002) COT Triplet', 'GPT3(003) COT Triplet','FLAN-XXL Triplet',  'FLAN-XXL COT Triplet', 'FLAN-UL2 Triplet',  'FLAN-UL2 COT Triplet','GPT3(002) COT Pairwise', 'GPT3(003) Pairwise','GPT3(003) COT Pairwise', 'FLAN-UL2 Pairwise',  'FLAN-UL2 COT Pairwise','GPT3(002)(unver)', 'GPT embedding', 'FLAN xl (ver)',  'FLAN xxl (ver)', 'Word2Vec', 'CLIP']
corr = corr.reindex(names)
corr = corr.reindex(names, axis=1)



# # Generate a mask for the upper triangle; True = do NOT show
# mask = np.zeros_like(corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(13, 11))

# Generate a custom diverging colormap
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmap = plt.cm.YlOrRd

# Draw the heatmap with the mask and correct aspect ratio
# More details at https://seaborn.pydata.org/generated/seaborn.heatmap.html
sns.heatmap(
    corr,          # The data to plot
    # mask=mask,     # Mask some cells
    cmap=cmap,     # What colors to plot the heatmap as
    annot=True,    # Should the values be plotted in the cells?
    vmax=1,       # The maximum value of the legend. All higher vals will be same color
    vmin=0,      # The minimum value of the legend. All lower vals will be same color
    center=0.5,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .5}  # Extra kwargs for the legend; in this case, shrink by 50%
)
#remove the y-axis label
ax.set_ylabel('')

# Increase the size of the labels of make the resolution better
ax.tick_params(axis='both', which='major', labelsize=14)

#make the font such that it can be edited in illustrator
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#save the figure as a pdf
plt.savefig('../graphs/full_heatmap.pdf', bbox_inches='tight')
# Out:
# Failed to start the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
!#  Ganked from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
# Assumes you have run `pip install numpy pandas matplotlib scikit-learn seaborn`

# Standard imports
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# For this example we'll use Seaborn, which has some nice built in plots
import seaborn as sns

corr = pd.read_csv('../results/dsm_the_whole_correlation_table.csv', index_col=1, header=0)
corr = corr.iloc[:, 1:]
# replace all the float values with the square of the float values
corr = corr.applymap(lambda x: x**2)
corr

#rename rows and columns using the follwing list
names = ['Human norms', 'Word2Vec', 'CLIP', 'GPT3(002)(unver)', 'GPT3(002)(ver)', 'Human triplet', 'GPT3(002) triplet', 'GPT embedding', 'Human Pairwise', 'GPT3(003) Pairwise', 
         'FLAN-XXL Triplet',  'FLAN-XXL COT Triplet', 'FLAN-UL2 Triplet',  'FLAN-UL2 COT Triplet', 'GPT3(003) COT Triplet', 'GPT3(002) COT Triplet', 'FLAN-UL2 Pairwise',  'FLAN-UL2 COT Pairwise', 'GPT3(003) COT Pairwise', 'GPT3(002) COT Pairwise', 'GPT3(002) Pairwise', 'FLAN-XXL(ver)']


corr.index = names
corr.columns = names

#rearange the rows and columns to match the following order
names = ['Human norms', 'Human triplet', 'Human Pairwise', 'GPT3(002)(ver)', 'GPT3(002) triplet',  'GPT3(002) Pairwise', 'GPT3(002) COT Triplet', 'GPT3(002) COT Pairwise', 'GPT3(003) Pairwise', 'GPT3(003) COT Triplet', 'GPT3(003) COT Pairwise','FLAN-XXL(ver)', 'FLAN-XXL Triplet',  'FLAN-XXL COT Triplet', 'FLAN-UL2 Triplet', 'FLAN-UL2 Pairwise', 'FLAN-UL2 COT Triplet', 'FLAN-UL2 COT Pairwise','GPT3(002)(unver)', 'GPT embedding', 'Word2Vec', 'CLIP']
corr = corr.reindex(names)
corr = corr.reindex(names, axis=1)



# # Generate a mask for the upper triangle; True = do NOT show
# mask = np.zeros_like(corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(13, 11))

# Generate a custom diverging colormap
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmap = plt.cm.YlOrRd

# Draw the heatmap with the mask and correct aspect ratio
# More details at https://seaborn.pydata.org/generated/seaborn.heatmap.html
sns.heatmap(
    corr,          # The data to plot
    # mask=mask,     # Mask some cells
    cmap=cmap,     # What colors to plot the heatmap as
    annot=True,    # Should the values be plotted in the cells?
    vmax=1,       # The maximum value of the legend. All higher vals will be same color
    vmin=0,      # The minimum value of the legend. All lower vals will be same color
    center=0.5,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .5}  # Extra kwargs for the legend; in this case, shrink by 50%
)
#remove the y-axis label
ax.set_ylabel('')

# Increase the size of the labels of make the resolution better
ax.tick_params(axis='both', which='major', labelsize=14)

#make the font such that it can be edited in illustrator
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#save the figure as a pdf
plt.savefig('../graphs/full_heatmap.pdf', bbox_inches='tight')

# %% [markdown]
# # graphs for the paper

# %% [markdown]
# ## bar plots

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### feature listing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

names = ['Human norms', 'Word2Vec', 'CLIP', 'GPT3(002)(unver)', 'GPT3(002)(ver)', 'Human triplet',
         'GPT3(002) triplet', 'GPT embedding', 'Human Pairwise', 'GPT3(003) Pairwise', 'FLAN-XXL Triplet',
         'FLAN-UL2 Triplet', 'FLAN-UL2 Pairwise', 'GPT3(002) Pairwise', 'FLAN-XXL(ver)']
task = [4, 1, 1, 4, 4, 3, 3, 1, 2, 2, 3, 3, 2, 2, 4]
name_to_task = dict(zip(names, task))
task_to_color = {1: 'red', 2: 'blue', 3: 'green', 4: 'orange'}  # Define your color mapping

# Load and process data for the first graph (remains the same)
corr = pd.read_csv('../results/dsm_no_cot_the_whole_correlation_table.csv', index_col=1, header=0)
corr = corr.iloc[:, 1:]
corr = corr.applymap(lambda x: x ** 2)
corr.index = names
corr.columns = names


human_f = corr['Human norms'].sort_values(ascending=False)
df = pd.DataFrame(index=human_f.index, columns=['correlation', 'task'])
df['correlation'] = human_f
df['task'] = df.index.map(name_to_task)

#remove indexes where the word 'Human' appears
df = df[~df.index.str.contains('Human')]
# remove the index is any of the values in the columns is NaN
df = df.dropna(axis=0, how='any')

# sort first by task. The order of the tasks is f, t, p, e
# then sort by correlation within each task
df = df.sort_values(by=['task', 'correlation'], ascending=False)
order = df.index

# Create the first plot
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(10, 12))
axs[0].bar(df.index, df['correlation'], color=df['task'].map(task_to_color))
axs[0].set_title('Correlation of model representations with Human Feature Listing representations')
axs[0].set_xticklabels([])
axs[0].set_ylim(0, 1)

# Load and process data for the second plot
human_t = corr['Human triplet'].sort_values(ascending=False)
df = pd.DataFrame(index=human_t.index, columns=['correlation', 'task'])
df['correlation'] = human_t
df['task'] = df.index.map(name_to_task)
#remove indexes where the word 'Human' appears
df = df[~df.index.str.contains('Human')]
# remove the index is any of the values in the columns is NaN
df = df.dropna(axis=0, how='any')

# use the same order as the first plot
df = df.reindex(order)

# Create the second plot below the first one
axs[1].bar(df.index, df['correlation'], color=df['task'].map(task_to_color))
axs[1].set_title('Correlation of model representations with Human Triplet representations')
axs[1].set_xticklabels([])
axs[1].set_ylim(0, 1)

# Load and process data for the third plot
human_p = corr['Human Pairwise'].sort_values(ascending=False)
df = pd.DataFrame(index=human_p.index, columns=['correlation', 'task'])
df['correlation'] = human_p
df['task'] = df.index.map(name_to_task)

#remove indexes where the word 'Human' appears
df = df[~df.index.str.contains('Human')]
# remove the index is any of the values in the columns is NaN
df = df.dropna(axis=0, how='any')

# sort first by task. The order of the tasks is f, t, p, e
# then sort by correlation within each task
# df = df.sort_values(by=['task', 'correlation'], ascending=False)
df = df.reindex(order)

# Create the third plot below the second one
axs[2].bar(df.index, df['correlation'], color=df['task'].map(task_to_color))
axs[2].set_title('Correlation of model representations with Human Pairwise representations')
axs[2].set_xticklabels(df.index, rotation=90)
axs[2].set_ylim(0, 1)

# Add the legend on the top chart
red_patch = mpatches.Patch(color='red', label='Feature Listing')
blue_patch = mpatches.Patch(color='blue', label='Triplet')
green_patch = mpatches.Patch(color='green', label='Pairwise')
orange_patch = mpatches.Patch(color='orange', label='Embedding')
axs[0].legend(handles=[orange_patch, green_patch, blue_patch, red_patch], loc='upper right', bbox_to_anchor=(1, 1), ncol=2)

# Adjust the layout and add space for labels
fig.tight_layout()
fig.subplots_adjust(bottom=0.2, left=0.1)

# Set a single y-label on the leftmost subplot
fig.text(0.02, 0.5, 'R^2', va='center', rotation='vertical', fontsize=16)

# Set a single x-label below the bottom subplot
# fig.text(0.5, 0.05, 'Model representations', ha='center', fontsize=14)
#make the font such that it can be edited in illustrator
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# increase the size of the text
plt.rcParams.update({'font.size': 16})

# create some margin at the bottom
# plt.subplots_adjust(bottom=0.2)

#save the figure as a pdf with dpi 300
plt.savefig('../graphs/bar_graph.pdf', bbox_inches='tight', dpi=300)
# Out:
# /tmp/ipykernel_2264968/3429054026.py:80: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[2].set_xticklabels(df.index, rotation=90)

# %%
# human corr heatmap

!#  Ganked from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
# Assumes you have run `pip install numpy pandas matplotlib scikit-learn seaborn`

# Standard imports
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# For this example we'll use Seaborn, which has some nice built in plots
import seaborn as sns

corr = pd.read_csv('../results/humans_all_tasks_correlation_table.csv', index_col=1, header=0)
corr = corr.iloc[:, 1:]
# replace all the float values with the square of the float values
corr = corr.applymap(lambda x: x**2)
corr

#rename rows and columns using the follwing list
names = ['Feature Listing', 'Triplet','Pairwise']


corr.index = names
corr.columns = names

#rearange the rows and columns to match the following order
names = ['Feature Listing', 'Triplet','Pairwise']
corr = corr.reindex(names)
corr = corr.reindex(names, axis=1)



# # Generate a mask for the upper triangle; True = do NOT show
# mask = np.zeros_like(corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(13, 11))

# Generate a custom diverging colormap
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmap = plt.cm.YlOrRd

# Draw the heatmap with the mask and correct aspect ratio
# More details at https://seaborn.pydata.org/generated/seaborn.heatmap.html
sns.heatmap(
    corr,          # The data to plot
    # mask=mask,     # Mask some cells
    cmap=cmap,     # What colors to plot the heatmap as
    annot=True,    # Should the values be plotted in the cells?
    vmax=1,       # The maximum value of the legend. All higher vals will be same color
    vmin=0,      # The minimum value of the legend. All lower vals will be same color
    center=0.5,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .5}  # Extra kwargs for the legend; in this case, shrink by 50%
)
#remove the y-axis label
ax.set_ylabel('')

# Increase the size of the labels of make the resolution better
ax.tick_params(axis='both', which='major', labelsize=14)

#make the font such that it can be edited in illustrator
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#save the figure as a pdf
plt.savefig('../graphs/human_heatmap.pdf', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 5))

ax1 = axes[0]
ax1.set_title('Humans')


corr = pd.read_csv('../results/humans_all_tasks_correlation_table.csv', index_col=1, header=0)
corr = corr.iloc[:, 1:]
# replace all the float values with the square of the float values
corr = corr.applymap(lambda x: x**2)
corr

#rename rows and columns using the follwing list
names = ['Feature Listing', 'Triplet','Pairwise']


corr.index = names
corr.columns = names

#rearange the rows and columns to match the following order
names = ['Feature Listing', 'Triplet','Pairwise']
corr = corr.reindex(names)
corr = corr.reindex(names, axis=1)



# # Generate a mask for the upper triangle; True = do NOT show
# mask = np.zeros_like(corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# Generate a custom diverging colormap
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmap = plt.cm.YlOrRd

# Draw the heatmap with the mask and correct aspect ratio
# More details at https://seaborn.pydata.org/generated/seaborn.heatmap.html
sns.heatmap(
    corr,          # The data to plot
    # mask=mask,     # Mask some cells
    cmap=cmap, 
    ax = ax1,# What colors to plot the heatmap as
    annot=True,    # Should the values be plotted in the cells?
    vmax=1,       # The maximum value of the legend. All higher vals will be same color
    vmin=0,      # The minimum value of the legend. All lower vals will be same color
    center=0.5,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .5},
    cbar=False# Extra kwargs for the legend; in this case, shrink by 50%
)
#remove the y-axis label
ax1.set_ylabel('')

# Increase the size of the labels of make the resolution better
ax1.tick_params(axis='both', which='major', labelsize=14)





ax1 = axes[1]
ax1.set_title('GPT-3 (002)')


corr = pd.read_csv('../results/text-davinci-002_all_tasks_correlation_table.csv', index_col=1, header=0)
corr = corr.iloc[:, 1:]
# replace all the float values with the square of the float values
corr = corr.applymap(lambda x: x**2)
corr

#rename rows and columns using the follwing list
names = ['Feature Listing', 'Triplet','Pairwise']


corr.index = names
corr.columns = names

#rearange the rows and columns to match the following order
names = ['Feature Listing', 'Triplet','Pairwise']
corr = corr.reindex(names)
corr = corr.reindex(names, axis=1)



# # Generate a mask for the upper triangle; True = do NOT show
# mask = np.zeros_like(corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True


# Generate a custom diverging colormap
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmap = plt.cm.YlOrRd

# Draw the heatmap with the mask and correct aspect ratio
# More details at https://seaborn.pydata.org/generated/seaborn.heatmap.html
a = sns.heatmap(
    corr,          # The data to plot
    # mask=mask,     # Mask some cells
    cmap=cmap, 
    ax = ax1,# What colors to plot the heatmap as
    annot=True,    # Should the values be plotted in the cells?
    vmax=1,       # The maximum value of the legend. All higher vals will be same color
    vmin=0,      # The minimum value of the legend. All lower vals will be same color
    center=0.5,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .5},
    cbar=False# Extra kwargs for the legend; in this case, shrink by 50%
)
#remove the y-axis label
ax1.set_ylabel('')
ax1.set_yticks([])

# Increase the size of the labels of make the resolution better
ax1.tick_params(axis='both', which='major', labelsize=14)


ax1 = axes[2]
ax1.set_title('FLAN-XXL')


corr = pd.read_csv('../results/flan-xxl_all_tasks_correlation_table.csv', index_col=1, header=0)
corr = corr.iloc[:, 1:]
# replace all the float values with the square of the float values
corr = corr.applymap(lambda x: x**2)
corr

#rename rows and columns using the follwing list
names = ['Feature Listing', 'Triplet','Pairwise']


corr.index = names
corr.columns = names

#rearange the rows and columns to match the following order
names = ['Feature Listing', 'Triplet','Pairwise']
corr = corr.reindex(names)
corr = corr.reindex(names, axis=1)



# # Generate a mask for the upper triangle; True = do NOT show
# mask = np.zeros_like(corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True


# Generate a custom diverging colormap
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmap = plt.cm.YlOrRd

# Draw the heatmap with the mask and correct aspect ratio
# More details at https://seaborn.pydata.org/generated/seaborn.heatmap.html
sns.heatmap(
    corr,          # The data to plot
    # mask=mask,     # Mask some cells
    cmap=cmap, 
    ax = ax1,# What colors to plot the heatmap as
    annot=True,    # Should the values be plotted in the cells?
    vmax=1,       # The maximum value of the legend. All higher vals will be same color
    vmin=0,      # The minimum value of the legend. All lower vals will be same color
    center=0.5,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .5},
    cbar=False# Extra kwargs for the legend; in this case, shrink by 50%
)
#remove the y-axis label
ax1.set_ylabel('')
ax1.set_yticks([])

# Increase the size of the labels of make the resolution better
ax1.tick_params(axis='both', which='major', labelsize=14)




# ax1 = axes[3]
# ax1.set_title('FLAN-XXL')


# corr = pd.read_csv('../results/flan-xxl_all_tasks_correlation_table.csv', index_col=1, header=0)
# corr = corr.iloc[:, 1:]
# # replace all the float values with the square of the float values
# corr = corr.applymap(lambda x: x**2)
# corr

# #rename rows and columns using the follwing list
# names = ['Feature Listing', 'Triplet','Pairwise']


# corr.index = names
# corr.columns = names

# #rearange the rows and columns to match the following order
# names = ['Feature Listing', 'Triplet','Pairwise']
# corr = corr.reindex(names)
# corr = corr.reindex(names, axis=1)



# # # Generate a mask for the upper triangle; True = do NOT show
# # mask = np.zeros_like(corr, dtype=np.bool)
# # mask[np.triu_indices_from(mask)] = True


# # Generate a custom diverging colormap
# # cmap = sns.diverging_palette(220, 10, as_cmap=True)
# cmap = plt.cm.YlOrRd

# # Draw the heatmap with the mask and correct aspect ratio
# # More details at https://seaborn.pydata.org/generated/seaborn.heatmap.html
# a = sns.heatmap(
#     corr,          # The data to plot
#     # mask=mask,     # Mask some cells
#     cmap=cmap, 
#     ax = ax1,# What colors to plot the heatmap as
#     annot=True,    # Should the values be plotted in the cells?
#     vmax=1,       # The maximum value of the legend. All higher vals will be same color
#     vmin=0,      # The minimum value of the legend. All lower vals will be same color
#     center=0.5,      # The center value of the legend. With divergent cmap, where white is
#     square=True,   # Force cells to be square
#     linewidths=.5, # Width of lines that divide cells
#     cbar_kws={"shrink": .5},
#     cbar=False# Extra kwargs for the legend; in this case, shrink by 50%
# )
# #remove the y-axis label
# ax1.set_ylabel('')
# ax1.set_yticks([])

# Adjust the spacing between subplots
plt.tight_layout()
try:
    fig.colorbar(a, ax=axes, location='right', shrink=0.6)
except:
    pass


# Increase the size of the labels of make the resolution better
ax1.tick_params(axis='both', which='major', labelsize=14)
import matplotlib
# cmap = mcolors.LinearSegmentedColormap.from_list('YlOrRd', [(0, '#FFFFCC'), (1, '#E31A1C')])
# cbar = fig.colorbar(im, cmap='YlOrRd', ax=axes.ravel().tolist(), shrink=0.95)
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
#save the figure as a pdf

#change cmap of plt to YlOrRd
# plt.set_cmap('YlOrRd')

#make colorbar with plt.colorbar
# cbar = plt.colorbar()


plt.savefig('../graphs/final_heatmap.pdf', bbox_inches='tight')

# %%
!#  Ganked from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
# Assumes you have run `pip install numpy pandas matplotlib scikit-learn seaborn`

# Standard imports
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# For this example we'll use Seaborn, which has some nice built in plots
import seaborn as sns

corr = pd.read_csv('../results/dsm_no_cot_the_whole_correlation_table.csv', index_col=1, header=0)
corr = corr.iloc[:, 1:]
# replace all the float values with the square of the float values
corr = corr.applymap(lambda x: x**2)
corr

#rename rows and columns using the follwing list
names = ['Human norms', 'Word2Vec', 'CLIP', 'GPT-3(002)(unver)', 'GPT-3(002)(ver)', 'Human triplet',
         'GPT-3(002) triplet', 'GPT embedding', 'Human Pairwise', 'GPT-3(003) Pairwise', 'FLAN-XXL Triplet',
         'FLAN-UL2 Triplet', 'FLAN-UL2 Pairwise', 'GPT-3(002) Pairwise', 'FLAN-XXL(ver)']

corr.index = names
corr.columns = names

#rearange the rows and columns to match the following order
names = ['Human norms', 'Human triplet', 'Human Pairwise', 'GPT-3(002)(ver)', 'GPT-3(002) triplet',  'GPT-3(002) Pairwise', 'GPT-3(003) Pairwise', 'FLAN-XXL(ver)', 'FLAN-XXL Triplet', 'FLAN-UL2 Triplet', 'FLAN-UL2 Pairwise', 'GPT-3(002)(unver)', 'GPT embedding', 'Word2Vec', 'CLIP']
corr = corr.reindex(names)
corr = corr.reindex(names, axis=1)



# # Generate a mask for the upper triangle; True = do NOT show
# mask = np.zeros_like(corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(13, 11))

# Generate a custom diverging colormap
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmap = plt.cm.YlOrRd

# Draw the heatmap with the mask and correct aspect ratio
# More details at https://seaborn.pydata.org/generated/seaborn.heatmap.html
sns.heatmap(
    corr,          # The data to plot
    # mask=mask,     # Mask some cells
    cmap=cmap,     # What colors to plot the heatmap as
    annot=True,    # Should the values be plotted in the cells?
    vmax=1,       # The maximum value of the legend. All higher vals will be same color
    vmin=0,      # The minimum value of the legend. All lower vals will be same color
    center=0.5,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .5}  # Extra kwargs for the legend; in this case, shrink by 50%
)
#remove the y-axis label
ax.set_ylabel('')

# Increase the size of the labels of make the resolution better
ax.tick_params(axis='both', which='major', labelsize=14)

#make the font such that it can be edited in illustrator
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#save the figure as a pdf
plt.savefig('../graphs/no_cot_full_heatmap.pdf', bbox_inches='tight')

# %% [markdown]
# # Rebuttal

# %% [markdown]
# ## Only Cot heatplot

# %%
!#  Ganked from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
# Assumes you have run `pip install numpy pandas matplotlib scikit-learn seaborn`

# Standard imports
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# For this example we'll use Seaborn, which has some nice built in plots
import seaborn as sns

corr = pd.read_csv('../results/dsm_the_whole_correlation_table_rebuttal.csv', index_col=1, header=0)
corr = corr.iloc[:, 1:]
# replace all the float values with the square of the float values
corr = corr.applymap(lambda x: x**2)
corr

#rename rows and columns using the follwing list
names = ['Human norms', 'Word2Vec', 'CLIP', 'GPT3(002)(unver)', 'GPT3(002)(ver)', 'Human triplet', 'GPT3(002) triplet', 'GPT embedding', 'Human Pairwise', 'GPT3(003) Pairwise', 
         'FLAN-XXL Triplet',  'FLAN-XXL COT Triplet', 'FLAN-UL2 Triplet',  'FLAN-UL2 COT Triplet', 'GPT3(003) COT Triplet', 'GPT3(002) COT Triplet', 'FLAN-UL2 Pairwise',  'FLAN-UL2 COT Pairwise', 'GPT3(003) COT Pairwise', 'GPT3(002) COT Pairwise', 'GPT3(002) Pairwise', 'FLAN-XXL(ver)', 'GPT3 (002) Semantic Pairwise', 'FLAN-XXL Semantic Triplet', 'GPT3(002) Semantic triplet']


corr.index = names
corr.columns = names

#rearange the rows and columns to match the following order
names = ['Human norms', 'Human triplet', 'Human Pairwise', 'GPT3(002)(ver)', 'GPT3(002) triplet', 'GPT3(002) Semantic triplet', 'GPT3(002) Pairwise', 'GPT3 (002) Semantic Pairwise', 'GPT3(002) COT Triplet', 'GPT3(002) COT Pairwise', 'GPT3(003) Pairwise', 'GPT3(003) COT Triplet', 'GPT3(003) COT Pairwise','FLAN-XXL(ver)', 'FLAN-XXL Triplet',   'FLAN-XXL Semantic Triplet', 'FLAN-XXL COT Triplet', 'FLAN-UL2 Triplet', 'FLAN-UL2 Pairwise', 'FLAN-UL2 COT Triplet', 'FLAN-UL2 COT Pairwise','GPT3(002)(unver)', 'GPT embedding', 'Word2Vec', 'CLIP']
corr = corr.reindex(names)
corr = corr.reindex(names, axis=1)



# # Generate a mask for the upper triangle; True = do NOT show
# mask = np.zeros_like(corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(13, 11))

# Generate a custom diverging colormap
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmap = plt.cm.YlOrRd

# Draw the heatmap with the mask and correct aspect ratio
# More details at https://seaborn.pydata.org/generated/seaborn.heatmap.html
sns.heatmap(
    corr,          # The data to plot
    # mask=mask,     # Mask some cells
    cmap=cmap,     # What colors to plot the heatmap as
    annot=True,    # Should the values be plotted in the cells?
    vmax=1,       # The maximum value of the legend. All higher vals will be same color
    vmin=0,      # The minimum value of the legend. All lower vals will be same color
    center=0.5,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .5}  # Extra kwargs for the legend; in this case, shrink by 50%
)
#remove the y-axis label
ax.set_ylabel('')

# Increase the size of the labels of make the resolution better
ax.tick_params(axis='both', which='major', labelsize=14)

#make the font such that it can be edited in illustrator
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#save the figure as a pdf
# plt.savefig('../graphs/full_heatmap.pdf', bbox_inches='tight')

# %%
# remove ['GPT3(002)(ver)', 'GPT3(002) triplet', 'GPT3(002) Pairwise', 'GPT3(003) Pairwise', 'GPT3(003) Triplet'] rows and colimns from corr
corr = corr.drop(['GPT3(002)(ver)', 'GPT3(002) triplet', 'GPT3(002) Pairwise', 'GPT3 (002) Semantic Pairwise', 'GPT3(003) Pairwise', 'FLAN-XXL(ver)', 'FLAN-XXL Triplet', 'FLAN-UL2 Triplet', 'FLAN-UL2 Pairwise', 'GPT3(002)(unver)', 'GPT embedding', 'Word2Vec', 'CLIP'], axis=0)
corr = corr.drop(['GPT3(002)(ver)', 'GPT3(002) triplet', 'GPT3(002) Pairwise', 'GPT3 (002) Semantic Pairwise', 'GPT3(003) Pairwise', 'FLAN-XXL(ver)', 'FLAN-XXL Triplet', 'FLAN-UL2 Triplet', 'FLAN-UL2 Pairwise', 'GPT3(002)(unver)', 'GPT embedding', 'Word2Vec', 'CLIP'], axis=1)
corr
# Out:
#                         Human norms  Human triplet  Human Pairwise  \
# Human norms                1.000000       0.959406        0.837196
# Human triplet              0.959406       1.000000        0.715737
# Human Pairwise             0.837196       0.715737        1.000000
# GPT3(002) COT Triplet      0.910713       0.913515        0.725396
# GPT3(002) COT Pairwise     0.242659       0.138845        0.448323
# GPT3(003) COT Triplet      0.944401       0.965297        0.738498
# GPT3(003) COT Pairwise     0.159515       0.074466        0.371766
# FLAN-XXL COT Triplet       0.957330       0.994367        0.728303
# FLAN-UL2 Triplet           0.008644       0.002065        0.039433
# FLAN-UL2 Pairwise          0.245507       0.125841        0.486963
# FLAN-UL2 COT Triplet       0.868233       0.846477        0.748231
# FLAN-UL2 COT Pairwise      0.302567       0.181403        0.535297
# GPT3(002)(unver)           0.294057       0.169850        0.529563
# ...

# %%
# # Generate a mask for the upper triangle; True = do NOT show
# mask = np.zeros_like(corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(13, 11))

# Generate a custom diverging colormap
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmap = plt.cm.YlOrRd

# Draw the heatmap with the mask and correct aspect ratio
# More details at https://seaborn.pydata.org/generated/seaborn.heatmap.html
sns.heatmap(
    corr,          # The data to plot
    # mask=mask,     # Mask some cells
    cmap=cmap,     # What colors to plot the heatmap as
    annot=True,    # Should the values be plotted in the cells?
    vmax=1,       # The maximum value of the legend. All higher vals will be same color
    vmin=0,      # The minimum value of the legend. All lower vals will be same color
    center=0.5,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .5}  # Extra kwargs for the legend; in this case, shrink by 50%
)
#remove the y-axis label
ax.set_ylabel('')

# Increase the size of the labels of make the resolution better
ax.tick_params(axis='both', which='major', labelsize=14)

#make the font such that it can be edited in illustrator
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.savefig('../graphs/only_cot.pdf', bbox_inches='tight')
