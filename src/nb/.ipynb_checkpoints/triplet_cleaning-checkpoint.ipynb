# %%
import pandas as pd
import numpy as np

# %%
trips = pd.read_csv('../../results/reptile_tool/davinci_triplet_feature_list_pruned.csv', index_col=1)

# %%
trips
# Out:
#       Unnamed: 0       Anchor    Concept1     Concept2 Category  \
# 0             13          Saw   Alligator       Caiman     tool
# 1             64    Crocodile   Alligator  Screwdriver  reptile
# 2             65   Salamander   Alligator         Nail  reptile
# 3             74    Chameleon   Alligator      Oil can  reptile
# 4             96          Saw   Alligator         Toad     tool
# ...          ...          ...         ...          ...      ...
# 1459        1116      Oil can   Alligator       Vacuum     tool
# 1460        1248   Lawn Mower       Gecko       Vacuum     tool
# 1461        1298   Lawn Mower       Knife       Vacuum     tool
# 1462        1313       Hammer  Boa python       Vacuum     tool
# 1463        1384  Screwdriver  Boa python       Vacuum     tool
#
#       estimated_tokens  real_tokens  \
# 0                   39           40
# 1                   43           45
# 2                   42           42
# 3                   42           42
# ...

# %%
items = np.unique(trips.to_numpy())

# %%
item_ind_dict = dict(zip(items,range(items.shape[0])))

# %%
def make_inds(x):
    y = [item_ind_dict[i] for i in x.values]
    return(y)

# %%
trips2 = trips.apply(make_inds)

# %%
trips2.to_csv('tim_triplets_2_inds.csv',index=None)

# %%
for i,row in trips2.iterrows():
    print(f"- [{row[0]},{row[1]},{row[2]}]")
# Out:
# - [34,3,240]
# - [155,87,88]
# - [134,88,207]
# - [144,242,106]
# - [49,252,18]
# - [58,116,222]
# - [193,216,2]
# - [163,75,217]
# - [277,224,181]
# - [78,274,209]
# - [277,172,115]
# - [193,127,29]
# - [75,103,57]
# - [1,205,209]
# - [215,103,235]
# - [215,223,89]
# - [234,97,131]
# - [67,20,128]
# - [187,178,25]
# - [52,275,120]
# - [184,243,54]
# - [284,114,225]
# - [52,254,206]
# - [269,24,241]
# - [255,154,141]
# - [32,199,178]
# - [121,238,154]
# - [130,57,184]
# - [105,123,190]
# - [65,33,112]
# - [192,54,132]
# - [183,12,90]
# - [177,192,281]
# - [149,20,200]
# - [12,254,9]
# - [183,117,196]
# - [48,102,165]
# - [20,94,258]
# - [20,49,139]
# - [90,244,202]
# - [102,74,5]
# - [182,226,169]
# - [236,53,164]
# - [236,203,221]
# - [222,44,208]
# - [164,261,252]
# - [286,148,161]
# - [228,43,54]
# - [159,6,229]
# - [195,235,159]
# - [38,94,31]
# - [76,11,86]
# - [281,129,12]
# - [101,198,177]
# - [86,253,116]
# - [0,115,233]
# - [273,13,141]
# - [251,69,56]
# - [11,10,199]
# ...

# %%
for i in item_ind_dict.keys():
    print(f'"{i}",')
# Out:
# "accordion",
# "alligator",
# "anchovy",
# "ant",
# "apple",
# "apricot",
# "apron",
# "archery bow",
# "army tank",
# "asparagus",
# "axe",
# "bagpipe",
# "banana",
# "bass guitar",
# "bassoon",
# "bathing suit",
# "bazooka",
# "bean",
# "beaver",
# "bee",
# "beet",
# "beetle",
# "belt",
# "bison",
# "blackberry",
# "blackbird",
# "blouse",
# "blueberry",
# "boa constrictor",
# "boat",
# "boots",
# "bottle",
# "brown bat",
# "brussels sprouts",
# "bumblebee",
# "bus",
# "butterfly",
# "camel",
# "can opener",
# "canary",
# "cannon",
# "cap",
# "car",
# "carp",
# "carpenter's level",
# "carriage",
# "cart",
# "cauliflower",
# "celery",
# "centipede",
# "chameleon",
# "cherry",
# "chicken",
# "chisel",
# "clementine",
# "club",
# "coat",
# "cobra",
# "cockroach",
# "coconut",
# "cod",
# "coffee maker",
# "colander",
# "corn",
# "costume",
# "cow",
# "cricket",
# "crocodile",
# "crow",
# "crowbar",
# "cuckoo",
# "cucumber",
# "cymbals",
# "dagger",
# "deer",
# "dinosaur",
# ...

# %%
trips2.shape
# Out:
# (234, 3)

# %%
responses = pd.read_csv('responses_tim_triplets2.csv')

# %%
responses
# Out:
#       head  left  right  winner     sampler  score              puid  \
# 0       22    56      5      56  Validation    2.0  126fb967d076afee
# 1      200    48    186      48  Validation    3.0  9c9f70488043c4f9
# 2       84    20    179      20  Validation    4.0  126fb967d076afee
# 3      156    60    122     122  Validation    5.0  9c9f70488043c4f9
# 4        1   205    209     205  Validation    6.0  126fb967d076afee
# ...    ...   ...    ...     ...         ...    ...               ...
# 8600    38   231    235     235  Validation  191.0  276c0e49228d6d67
# 8601   286   188    203     203  Validation  192.0  276c0e49228d6d67
# 8602    52   156     80      80  Validation  193.0  276c0e49228d6d67
# 8603    46   212    263     263  Validation  194.0  276c0e49228d6d67
# 8604    74   141    255     255  Validation  195.0  276c0e49228d6d67
#
#       response_time  network_latency  time_received  ...  left_filename  \
# ...

# %%
a = responses.groupby('puid')['puid_num_responses'].max()==234
a = a[a==True].index

# %%
responses_clean = responses[responses.puid.isin(a)].reset_index(drop=True)

# %%
responses_clean.to_csv('responses_princeton_triplets_clean.csv')

# %%
208*32
# Out:
# 6656
